# %%
# 导入必要的库
import matplotlib as mpl
import matplotlib.pyplot as plt
# 在Jupyter notebook中内联显示图表
# %matplotlib inline  
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
from tqdm.auto import tqdm  # 进度条库
import torch
import torch.nn as nn
import torch.nn.functional as F

# 打印Python版本信息
print(sys.version_info)

# 打印各个库的版本信息
for module in mpl, np, pd, sklearn, torch:
    print(module.__name__, module.__version__)
    
# 设置设备：如果有GPU则使用GPU，否则使用CPU
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
print(device)
# Out:
# sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)
# matplotlib 3.10.8
# numpy 2.3.5
# pandas 3.0.0
# sklearn 1.8.0
# torch 2.10.0+cu130
# cuda:0

# %% [markdown]
# # 预处理

# %%
# 加载FashionMNIST数据集
from torchvision import datasets, transforms

# 定义数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 将PIL图像或numpy数组转换为tensor,ToTensor会自动将图像转换为tensor，并归一化到[0,1]范围
    transforms.Normalize((0.2860,), (0.3530,))  # 标准化到[-1, 1]范围
])

# 下载并加载训练集
train_dataset = datasets.FashionMNIST(
    root='./data',  # 数据存储路径
    train=True,     # 加载训练集
    download=True,  # 如果数据不存在则下载
    transform=transform
)

# 下载并加载测试集
test_dataset = datasets.FashionMNIST(
    root='./data',
    train=False,    # 加载测试集
    download=True,
    transform=transform
)

# 打印数据集信息
print(f"训练集大小: {len(train_dataset)}")
print(f"测试集大小: {len(test_dataset)}")

# lables在这个路径https://github.com/zalandoresearch/fashion-mnist
# FashionMNIST类别标签
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
print(f"类别数量: {len(class_names)}")
print(f"类别标签: {class_names}")
# Out:
# 训练集大小: 60000
# 测试集大小: 10000
# 类别数量: 10
# 类别标签: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
from torch.utils.data import DataLoader

# 创建训练集和验证集的DataLoader
batch_size = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,  # 训练时打乱数据
    num_workers=2  # 使用多进程加载数据
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,  # 测试时不需要打乱
    num_workers=2
)

# %% [markdown]
# # 搭建DNN

# %%
import torch
import torch.nn as nn

class DNN(nn.Module):
    def __init__(self, input_size=28*28, num_classes=10, hidden_size=100, num_hidden_layers=19):
        super(DNN, self).__init__()
        
        # 初始化Sequential对象
        self.linear_relu_stack = nn.Sequential()
        
        # 输入层到第1隐藏层
        self.linear_relu_stack.add_module(f"Linear_0", nn.Linear(input_size, hidden_size))
        self.linear_relu_stack.add_module(f"BatchNorm_0", nn.BatchNorm1d(hidden_size))
        self.linear_relu_stack.add_module(f"ReLU_0", nn.ReLU())
        
        # 通过for循环添加隐藏层
        for i in range(1, num_hidden_layers):
            self.linear_relu_stack.add_module(f"Linear_{i}", nn.Linear(hidden_size, hidden_size))
            self.linear_relu_stack.add_module(f"BatchNorm_{i}", nn.BatchNorm1d(hidden_size))
            self.linear_relu_stack.add_module(f"ReLU_{i}", nn.ReLU())
        
        # 输出层
        self.linear_relu_stack.add_module(f"Linear_output", nn.Linear(hidden_size, num_classes))
    
    def forward(self, x):
        # 将图片展平
        x = x.view(x.size(0), -1)  # (batch_size, 28*28)
        x = self.linear_relu_stack(x)
        return x

# 创建模型实例
model = DNN(input_size=28*28, num_classes=10)

# 打印模型结构
print(model)
print(f"\n模型参数总数: {sum(p.numel() for p in model.parameters())}")
# Out:
# DNN(
#   (linear_relu_stack): Sequential(
#     (Linear_0): Linear(in_features=784, out_features=100, bias=True)
#     (BatchNorm_0): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_0): ReLU()
#     (Linear_1): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_1): ReLU()
#     (Linear_2): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_2): ReLU()
#     (Linear_3): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_3): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_3): ReLU()
#     (Linear_4): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_4): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_4): ReLU()
#     (Linear_5): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_5): ReLU()
#     (Linear_6): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_6): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_6): ReLU()
#     (Linear_7): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_7): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_7): ReLU()
#     (Linear_8): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_8): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_8): ReLU()
#     (Linear_9): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_9): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_9): ReLU()
#     (Linear_10): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_10): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_10): ReLU()
#     (Linear_11): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_11): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_11): ReLU()
#     (Linear_12): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_12): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_12): ReLU()
#     (Linear_13): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_13): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_13): ReLU()
#     (Linear_14): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_14): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_14): ReLU()
#     (Linear_15): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_15): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_15): ReLU()
#     (Linear_16): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_16): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_16): ReLU()
#     (Linear_17): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_17): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_17): ReLU()
#     (Linear_18): Linear(in_features=100, out_features=100, bias=True)
#     (BatchNorm_18): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (ReLU_18): ReLU()
#     (Linear_output): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
#
# 模型参数总数: 265110

# %%
# 输出每层参数的个数
for idx, (name, param) in enumerate(model.named_parameters()):
    print(f"层 {idx}: {name} 参数个数 = {param.numel()}")
# Out:
# 层 0: linear_relu_stack.Linear_0.weight 参数个数 = 78400
# 层 1: linear_relu_stack.Linear_0.bias 参数个数 = 100
# 层 2: linear_relu_stack.BatchNorm_0.weight 参数个数 = 100
# 层 3: linear_relu_stack.BatchNorm_0.bias 参数个数 = 100
# 层 4: linear_relu_stack.Linear_1.weight 参数个数 = 10000
# 层 5: linear_relu_stack.Linear_1.bias 参数个数 = 100
# 层 6: linear_relu_stack.BatchNorm_1.weight 参数个数 = 100
# 层 7: linear_relu_stack.BatchNorm_1.bias 参数个数 = 100
# 层 8: linear_relu_stack.Linear_2.weight 参数个数 = 10000
# 层 9: linear_relu_stack.Linear_2.bias 参数个数 = 100
# 层 10: linear_relu_stack.BatchNorm_2.weight 参数个数 = 100
# 层 11: linear_relu_stack.BatchNorm_2.bias 参数个数 = 100
# 层 12: linear_relu_stack.Linear_3.weight 参数个数 = 10000
# 层 13: linear_relu_stack.Linear_3.bias 参数个数 = 100
# 层 14: linear_relu_stack.BatchNorm_3.weight 参数个数 = 100
# 层 15: linear_relu_stack.BatchNorm_3.bias 参数个数 = 100
# 层 16: linear_relu_stack.Linear_4.weight 参数个数 = 10000
# 层 17: linear_relu_stack.Linear_4.bias 参数个数 = 100
# 层 18: linear_relu_stack.BatchNorm_4.weight 参数个数 = 100
# 层 19: linear_relu_stack.BatchNorm_4.bias 参数个数 = 100
# 层 20: linear_relu_stack.Linear_5.weight 参数个数 = 10000
# 层 21: linear_relu_stack.Linear_5.bias 参数个数 = 100
# 层 22: linear_relu_stack.BatchNorm_5.weight 参数个数 = 100
# 层 23: linear_relu_stack.BatchNorm_5.bias 参数个数 = 100
# 层 24: linear_relu_stack.Linear_6.weight 参数个数 = 10000
# 层 25: linear_relu_stack.Linear_6.bias 参数个数 = 100
# 层 26: linear_relu_stack.BatchNorm_6.weight 参数个数 = 100
# 层 27: linear_relu_stack.BatchNorm_6.bias 参数个数 = 100
# 层 28: linear_relu_stack.Linear_7.weight 参数个数 = 10000
# 层 29: linear_relu_stack.Linear_7.bias 参数个数 = 100
# 层 30: linear_relu_stack.BatchNorm_7.weight 参数个数 = 100
# 层 31: linear_relu_stack.BatchNorm_7.bias 参数个数 = 100
# 层 32: linear_relu_stack.Linear_8.weight 参数个数 = 10000
# 层 33: linear_relu_stack.Linear_8.bias 参数个数 = 100
# 层 34: linear_relu_stack.BatchNorm_8.weight 参数个数 = 100
# 层 35: linear_relu_stack.BatchNorm_8.bias 参数个数 = 100
# 层 36: linear_relu_stack.Linear_9.weight 参数个数 = 10000
# 层 37: linear_relu_stack.Linear_9.bias 参数个数 = 100
# 层 38: linear_relu_stack.BatchNorm_9.weight 参数个数 = 100
# 层 39: linear_relu_stack.BatchNorm_9.bias 参数个数 = 100
# 层 40: linear_relu_stack.Linear_10.weight 参数个数 = 10000
# 层 41: linear_relu_stack.Linear_10.bias 参数个数 = 100
# 层 42: linear_relu_stack.BatchNorm_10.weight 参数个数 = 100
# 层 43: linear_relu_stack.BatchNorm_10.bias 参数个数 = 100
# 层 44: linear_relu_stack.Linear_11.weight 参数个数 = 10000
# 层 45: linear_relu_stack.Linear_11.bias 参数个数 = 100
# 层 46: linear_relu_stack.BatchNorm_11.weight 参数个数 = 100
# 层 47: linear_relu_stack.BatchNorm_11.bias 参数个数 = 100
# 层 48: linear_relu_stack.Linear_12.weight 参数个数 = 10000
# 层 49: linear_relu_stack.Linear_12.bias 参数个数 = 100
# 层 50: linear_relu_stack.BatchNorm_12.weight 参数个数 = 100
# 层 51: linear_relu_stack.BatchNorm_12.bias 参数个数 = 100
# 层 52: linear_relu_stack.Linear_13.weight 参数个数 = 10000
# 层 53: linear_relu_stack.Linear_13.bias 参数个数 = 100
# 层 54: linear_relu_stack.BatchNorm_13.weight 参数个数 = 100
# 层 55: linear_relu_stack.BatchNorm_13.bias 参数个数 = 100
# 层 56: linear_relu_stack.Linear_14.weight 参数个数 = 10000
# 层 57: linear_relu_stack.Linear_14.bias 参数个数 = 100
# 层 58: linear_relu_stack.BatchNorm_14.weight 参数个数 = 100
# 层 59: linear_relu_stack.BatchNorm_14.bias 参数个数 = 100
# 层 60: linear_relu_stack.Linear_15.weight 参数个数 = 10000
# 层 61: linear_relu_stack.Linear_15.bias 参数个数 = 100
# 层 62: linear_relu_stack.BatchNorm_15.weight 参数个数 = 100
# 层 63: linear_relu_stack.BatchNorm_15.bias 参数个数 = 100
# 层 64: linear_relu_stack.Linear_16.weight 参数个数 = 10000
# 层 65: linear_relu_stack.Linear_16.bias 参数个数 = 100
# 层 66: linear_relu_stack.BatchNorm_16.weight 参数个数 = 100
# 层 67: linear_relu_stack.BatchNorm_16.bias 参数个数 = 100
# 层 68: linear_relu_stack.Linear_17.weight 参数个数 = 10000
# 层 69: linear_relu_stack.Linear_17.bias 参数个数 = 100
# 层 70: linear_relu_stack.BatchNorm_17.weight 参数个数 = 100
# 层 71: linear_relu_stack.BatchNorm_17.bias 参数个数 = 100
# 层 72: linear_relu_stack.Linear_18.weight 参数个数 = 10000
# 层 73: linear_relu_stack.Linear_18.bias 参数个数 = 100
# 层 74: linear_relu_stack.BatchNorm_18.weight 参数个数 = 100
# 层 75: linear_relu_stack.BatchNorm_18.bias 参数个数 = 100
# 层 76: linear_relu_stack.Linear_output.weight 参数个数 = 1000
# 层 77: linear_relu_stack.Linear_output.bias 参数个数 = 10

# %%
# 验证模型前向计算
# 创建一个随机输入张量，模拟MNIST图片数据
batch_size = 32
input_tensor = torch.randn(batch_size, 1, 28, 28)  # (batch_size, channels, height, width)

print(f"输入张量形状: {input_tensor.shape}")

# 前向传播
with torch.no_grad():  # 不需要计算梯度
    output = model(input_tensor)
    
print(f"输出张量形状: {output.shape}")
print(f"输出张量示例 (前5个样本的前5个类别概率):")
print(output[:5, :5])

# 验证输出维度是否正确
assert output.shape == (batch_size, 10), f"期望输出形状为 ({batch_size}, 10), 但得到 {output.shape}"
print("\n✅ 模型前向计算验证成功！")
# Out:
# 输入张量形状: torch.Size([32, 1, 28, 28])
# 输出张量形状: torch.Size([32, 10])
# 输出张量示例 (前5个样本的前5个类别概率):
# tensor([[ 0.1482, -0.0166, -0.5237, -0.6770,  0.2390],
#         [-0.2720,  0.2675, -0.2269, -0.0235,  0.1679],
#         [-0.3236, -0.1812,  0.3993, -0.4949,  0.5271],
#         [-0.4077, -0.0580,  0.0591, -0.2119,  0.1399],
#         [ 0.4225,  0.0051, -0.5949, -0.1766,  0.3092]])
#
# ✅ 模型前向计算验证成功！

# %%
for batch in train_loader:
    inputs, targets = batch
    print(inputs.shape)
    print(targets.shape)
    break
# Out:
# torch.Size([32, 1, 28, 28])
# torch.Size([32])

# %%
# 导入训练模块
from wangdao_train import Trainer

# 设置设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {device}")

# 初始化损失函数
criterion = torch.nn.CrossEntropyLoss()

# 初始化优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 初始化早停
early_stopping_kwargs = {
    'patience': 10,
    'min_delta': 0.001,
    'mode': 'max'
}

# 创建训练器
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    eval_step=500,
    early_stopping_kwargs=early_stopping_kwargs
)

# 开始训练
print("开始训练...")
trainer.train(num_epochs=20)
# Out:
# 使用设备: cuda
# 开始训练...
# [Step 500] Val Loss: 0.6942 Val Acc: 0.7586
# [Step 1000] Val Loss: 0.8019 Val Acc: 0.7222
# [Step 1500] Val Loss: 0.8068 Val Acc: 0.6733
# Epoch [1/20]  Train Loss: 0.8773  Train Acc: 0.6785
# [Step 2000] Val Loss: 0.7132 Val Acc: 0.7661
# [Step 2500] Val Loss: 0.7082 Val Acc: 0.7241
# [Step 3000] Val Loss: 0.6574 Val Acc: 0.7665
# [Step 3500] Val Loss: 0.7417 Val Acc: 0.7371
# Epoch [2/20]  Train Loss: 0.7426  Train Acc: 0.7230
# [Step 4000] Val Loss: 0.6598 Val Acc: 0.7752
# [Step 4500] Val Loss: 1.3009 Val Acc: 0.4327
# [Step 5000] Val Loss: 0.8086 Val Acc: 0.7044
# [Step 5500] Val Loss: 0.7302 Val Acc: 0.7414
# Epoch [3/20]  Train Loss: 0.9341  Train Acc: 0.6540
# [Step 6000] Val Loss: 0.7847 Val Acc: 0.7373
# [Step 6500] Val Loss: 0.7198 Val Acc: 0.7445
# [Step 7000] Val Loss: 0.7624 Val Acc: 0.7359
# [Step 7500] Val Loss: 0.5900 Val Acc: 0.7872
# Epoch [4/20]  Train Loss: 0.7347  Train Acc: 0.7499
# [Step 8000] Val Loss: 0.6010 Val Acc: 0.7980
# [Step 8500] Val Loss: 0.5491 Val Acc: 0.8112
# [Step 9000] Val Loss: 0.6252 Val Acc: 0.7996
# Epoch [5/20]  Train Loss: 0.6401  Train Acc: 0.7847
# [Step 9500] Val Loss: 0.6104 Val Acc: 0.7972
# [Step 10000] Val Loss: 0.5489 Val Acc: 0.8055
# [Step 10500] Val Loss: 0.5524 Val Acc: 0.8108
# [Step 11000] Val Loss: 0.6480 Val Acc: 0.7891
# Epoch [6/20]  Train Loss: 0.5555  Train Acc: 0.8111
# [Step 11500] Val Loss: 0.5742 Val Acc: 0.8150
# [Step 12000] Val Loss: 0.5226 Val Acc: 0.8262
# [Step 12500] Val Loss: 0.5120 Val Acc: 0.8278
# [Step 13000] Val Loss: 0.5359 Val Acc: 0.8210
# Epoch [7/20]  Train Loss: 0.5372  Train Acc: 0.8258
# [Step 13500] Val Loss: 0.5698 Val Acc: 0.8188
# [Step 14000] Val Loss: 0.5857 Val Acc: 0.8001
# [Step 14500] Val Loss: 0.4962 Val Acc: 0.8311
# [Step 15000] Val Loss: 0.4655 Val Acc: 0.8399
# Epoch [8/20]  Train Loss: 0.5208  Train Acc: 0.8272
# [Step 15500] Val Loss: 0.5505 Val Acc: 0.8141
# [Step 16000] Val Loss: 0.5156 Val Acc: 0.8351
# [Step 16500] Val Loss: 0.4505 Val Acc: 0.8431
# Epoch [9/20]  Train Loss: 0.5087  Train Acc: 0.8344
# [Step 17000] Val Loss: 0.5646 Val Acc: 0.8072
# [Step 17500] Val Loss: 0.4394 Val Acc: 0.8502
# [Step 18000] Val Loss: 0.5076 Val Acc: 0.8382
# [Step 18500] Val Loss: 0.4654 Val Acc: 0.8474
# Epoch [10/20]  Train Loss: 0.4526  Train Acc: 0.8478
# [Step 19000] Val Loss: 0.5066 Val Acc: 0.8364
# [Step 19500] Val Loss: 0.4337 Val Acc: 0.8560
# [Step 20000] Val Loss: 0.4795 Val Acc: 0.8384
# [Step 20500] Val Loss: 0.4244 Val Acc: 0.8557
# Epoch [11/20]  Train Loss: 0.4442  Train Acc: 0.8526
# [Step 21000] Val Loss: 0.5896 Val Acc: 0.8184
# [Step 21500] Val Loss: 0.4646 Val Acc: 0.8413
# [Step 22000] Val Loss: 0.4323 Val Acc: 0.8513
# [Step 22500] Val Loss: 0.4296 Val Acc: 0.8558
# Epoch [12/20]  Train Loss: 0.4416  Train Acc: 0.8527
# [Step 23000] Val Loss: 0.4582 Val Acc: 0.8554
# [Step 23500] Val Loss: 0.4234 Val Acc: 0.8633
# [Step 24000] Val Loss: 0.4345 Val Acc: 0.8468
# Epoch [13/20]  Train Loss: 0.4349  Train Acc: 0.8573
# [Step 24500] Val Loss: 0.4379 Val Acc: 0.8510
# [Step 25000] Val Loss: 0.4535 Val Acc: 0.8515
# [Step 25500] Val Loss: 0.4258 Val Acc: 0.8609
# [Step 26000] Val Loss: 0.4450 Val Acc: 0.8447
# Epoch [14/20]  Train Loss: 0.3899  Train Acc: 0.8681
# [Step 26500] Val Loss: 0.4397 Val Acc: 0.8561
# [Step 27000] Val Loss: 0.4122 Val Acc: 0.8557
# [Step 27500] Val Loss: 0.4181 Val Acc: 0.8616
# [Step 28000] Val Loss: 0.4166 Val Acc: 0.8595
# Epoch [15/20]  Train Loss: 0.4011  Train Acc: 0.8648
# [Step 28500] Val Loss: 0.4266 Val Acc: 0.8567
# Early stopping triggered at step 28500.

# %%
trainer.plot_curves()
